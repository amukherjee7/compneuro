# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# Pipeline for processing 24-well plate data and plotting rasters for the most active wells
def process_24_well_folder(folder_path, main_save_path):
    os.makedirs(main_save_path, exist_ok=True)
    csv_files = [f for f in os.listdir(folder_path) if f.endswith(".csv")]

    for file in csv_files:
        print(f"Processing file: {file}")
        file_path = os.path.join(folder_path, file)
        data = pd.read_csv(file_path)

        # Create a subfolder based on the file prefix (e.g., 000, 001, etc.)
        file_prefix = os.path.splitext(file)[0]
        save_path = os.path.join(main_save_path, file_prefix)
        os.makedirs(save_path, exist_ok=True)

        process_24_well_file(data, save_path, file_prefix)

def process_24_well_file(data, save_path, file_prefix):
    wells = [
        [f"A{i}" for i in range(1, 7)],
        [f"B{i}" for i in range(1, 7)],
        [f"C{i}" for i in range(1, 7)],
        [f"D{i}" for i in range(1, 7)],
    ]

    for row in wells:
        row_activities = {well: calculate_activity(data, well) for well in row}
        # Select the two most active wells in the row
        most_active_wells = sorted(row_activities, key=row_activities.get, reverse=True)[:2]
        for well in most_active_wells:
            plot_raster(data, well, save_path, file_prefix)

# Function to calculate total activity for a given well
def calculate_activity(data, well_name):
    well_columns = [col for col in data.columns if col.startswith(well_name)]
    return data[well_columns].sum().sum()

# Function to plot a raster for a single well
def plot_raster(data, well_name, save_path, file_prefix):
    well_columns = [col for col in data.columns if col.startswith(well_name)]
    interval_start = data["Interval_Start"]

    fig, ax = plt.subplots(figsize=(12, 8))
    for idx, electrode in enumerate(well_columns):
        spike_times = interval_start[data[electrode] == 1]
        ax.vlines(spike_times, idx + 0.5, idx + 1.5, color="black")

    ax.set_xlim(0, 300)  # Ensure consistent x-axis limits
    ax.set_xlabel("Time (s)", fontsize=14)
    ax.set_ylabel("Electrodes", fontsize=14)
    ax.set_title(f"24-well Raster Plot for Well {well_name}", fontsize=16)
    ax.set_yticks(range(1, len(well_columns) + 1))
    ax.set_yticklabels(well_columns, fontsize=8)
    plt.tight_layout()

    plot_path = os.path.join(save_path, f"{file_prefix}_{well_name}_24_well_raster.png")
    plt.savefig(plot_path)
    print(f"Saved raster plot for {well_name} at {plot_path}")
    plt.close()

# Example usage
folder_path = "rasters_data/24-well"  # Path to folder containing CSV files
main_save_path = "plots/rasters/24-well"  # Path to save plots organized into subfolders
process_24_well_folder(folder_path, main_save_path)
# Out:
# Processing file: (005)(000)_spike_counts.csv
# Saved raster plot for A1 at plots/rasters/24-well/(005)(000)_spike_counts/(005)(000)_spike_counts_A1_24_well_raster.png
# Saved raster plot for A2 at plots/rasters/24-well/(005)(000)_spike_counts/(005)(000)_spike_counts_A2_24_well_raster.png
# Saved raster plot for B3 at plots/rasters/24-well/(005)(000)_spike_counts/(005)(000)_spike_counts_B3_24_well_raster.png
# Saved raster plot for B1 at plots/rasters/24-well/(005)(000)_spike_counts/(005)(000)_spike_counts_B1_24_well_raster.png
# Saved raster plot for C1 at plots/rasters/24-well/(005)(000)_spike_counts/(005)(000)_spike_counts_C1_24_well_raster.png
# Saved raster plot for C2 at plots/rasters/24-well/(005)(000)_spike_counts/(005)(000)_spike_counts_C2_24_well_raster.png
# Saved raster plot for D4 at plots/rasters/24-well/(005)(000)_spike_counts/(005)(000)_spike_counts_D4_24_well_raster.png
# Saved raster plot for D5 at plots/rasters/24-well/(005)(000)_spike_counts/(005)(000)_spike_counts_D5_24_well_raster.png
# Processing file: (034)(000)_spike_counts.csv
# Saved raster plot for A5 at plots/rasters/24-well/(034)(000)_spike_counts/(034)(000)_spike_counts_A5_24_well_raster.png
# Saved raster plot for A4 at plots/rasters/24-well/(034)(000)_spike_counts/(034)(000)_spike_counts_A4_24_well_raster.png
# Saved raster plot for B4 at plots/rasters/24-well/(034)(000)_spike_counts/(034)(000)_spike_counts_B4_24_well_raster.png
# Saved raster plot for B2 at plots/rasters/24-well/(034)(000)_spike_counts/(034)(000)_spike_counts_B2_24_well_raster.png
# Saved raster plot for C5 at plots/rasters/24-well/(034)(000)_spike_counts/(034)(000)_spike_counts_C5_24_well_raster.png
# Saved raster plot for C2 at plots/rasters/24-well/(034)(000)_spike_counts/(034)(000)_spike_counts_C2_24_well_raster.png
# Saved raster plot for D3 at plots/rasters/24-well/(034)(000)_spike_counts/(034)(000)_spike_counts_D3_24_well_raster.png
# Saved raster plot for D4 at plots/rasters/24-well/(034)(000)_spike_counts/(034)(000)_spike_counts_D4_24_well_raster.png
# Processing file: (008)(000)_spike_counts.csv
# Saved raster plot for A4 at plots/rasters/24-well/(008)(000)_spike_counts/(008)(000)_spike_counts_A4_24_well_raster.png
# Saved raster plot for A5 at plots/rasters/24-well/(008)(000)_spike_counts/(008)(000)_spike_counts_A5_24_well_raster.png
# Saved raster plot for B1 at plots/rasters/24-well/(008)(000)_spike_counts/(008)(000)_spike_counts_B1_24_well_raster.png
# Saved raster plot for B2 at plots/rasters/24-well/(008)(000)_spike_counts/(008)(000)_spike_counts_B2_24_well_raster.png
# Saved raster plot for C4 at plots/rasters/24-well/(008)(000)_spike_counts/(008)(000)_spike_counts_C4_24_well_raster.png
# Saved raster plot for C1 at plots/rasters/24-well/(008)(000)_spike_counts/(008)(000)_spike_counts_C1_24_well_raster.png
# Saved raster plot for D6 at plots/rasters/24-well/(008)(000)_spike_counts/(008)(000)_spike_counts_D6_24_well_raster.png
# Saved raster plot for D1 at plots/rasters/24-well/(008)(000)_spike_counts/(008)(000)_spike_counts_D1_24_well_raster.png
# Processing file: (002)(000)_spike_counts.csv
# Saved raster plot for A1 at plots/rasters/24-well/(002)(000)_spike_counts/(002)(000)_spike_counts_A1_24_well_raster.png
# Saved raster plot for A2 at plots/rasters/24-well/(002)(000)_spike_counts/(002)(000)_spike_counts_A2_24_well_raster.png
# Saved raster plot for B2 at plots/rasters/24-well/(002)(000)_spike_counts/(002)(000)_spike_counts_B2_24_well_raster.png
# Saved raster plot for B1 at plots/rasters/24-well/(002)(000)_spike_counts/(002)(000)_spike_counts_B1_24_well_raster.png
# Saved raster plot for C1 at plots/rasters/24-well/(002)(000)_spike_counts/(002)(000)_spike_counts_C1_24_well_raster.png
# Saved raster plot for C2 at plots/rasters/24-well/(002)(000)_spike_counts/(002)(000)_spike_counts_C2_24_well_raster.png
# Saved raster plot for D1 at plots/rasters/24-well/(002)(000)_spike_counts/(002)(000)_spike_counts_D1_24_well_raster.png
# Saved raster plot for D2 at plots/rasters/24-well/(002)(000)_spike_counts/(002)(000)_spike_counts_D2_24_well_raster.png
# Processing file: (033)(000)_spike_counts.csv
# Saved raster plot for A5 at plots/rasters/24-well/(033)(000)_spike_counts/(033)(000)_spike_counts_A5_24_well_raster.png
# Saved raster plot for A2 at plots/rasters/24-well/(033)(000)_spike_counts/(033)(000)_spike_counts_A2_24_well_raster.png
# Saved raster plot for B4 at plots/rasters/24-well/(033)(000)_spike_counts/(033)(000)_spike_counts_B4_24_well_raster.png
# Saved raster plot for B1 at plots/rasters/24-well/(033)(000)_spike_counts/(033)(000)_spike_counts_B1_24_well_raster.png
# Saved raster plot for C5 at plots/rasters/24-well/(033)(000)_spike_counts/(033)(000)_spike_counts_C5_24_well_raster.png
# Saved raster plot for C4 at plots/rasters/24-well/(033)(000)_spike_counts/(033)(000)_spike_counts_C4_24_well_raster.png
# Saved raster plot for D2 at plots/rasters/24-well/(033)(000)_spike_counts/(033)(000)_spike_counts_D2_24_well_raster.png
# Saved raster plot for D3 at plots/rasters/24-well/(033)(000)_spike_counts/(033)(000)_spike_counts_D3_24_well_raster.png
# Processing file: (001)(000)_spike_counts.csv
# Saved raster plot for A1 at plots/rasters/24-well/(001)(000)_spike_counts/(001)(000)_spike_counts_A1_24_well_raster.png
# Saved raster plot for A2 at plots/rasters/24-well/(001)(000)_spike_counts/(001)(000)_spike_counts_A2_24_well_raster.png
# Saved raster plot for B1 at plots/rasters/24-well/(001)(000)_spike_counts/(001)(000)_spike_counts_B1_24_well_raster.png
# Saved raster plot for B2 at plots/rasters/24-well/(001)(000)_spike_counts/(001)(000)_spike_counts_B2_24_well_raster.png
# Saved raster plot for C1 at plots/rasters/24-well/(001)(000)_spike_counts/(001)(000)_spike_counts_C1_24_well_raster.png
# Saved raster plot for C2 at plots/rasters/24-well/(001)(000)_spike_counts/(001)(000)_spike_counts_C2_24_well_raster.png
# Saved raster plot for D1 at plots/rasters/24-well/(001)(000)_spike_counts/(001)(000)_spike_counts_D1_24_well_raster.png
# Saved raster plot for D2 at plots/rasters/24-well/(001)(000)_spike_counts/(001)(000)_spike_counts_D2_24_well_raster.png
# Processing file: (030)(000)_spike_counts.csv
# Saved raster plot for A5 at plots/rasters/24-well/(030)(000)_spike_counts/(030)(000)_spike_counts_A5_24_well_raster.png
# Saved raster plot for A3 at plots/rasters/24-well/(030)(000)_spike_counts/(030)(000)_spike_counts_A3_24_well_raster.png
# Saved raster plot for B1 at plots/rasters/24-well/(030)(000)_spike_counts/(030)(000)_spike_counts_B1_24_well_raster.png
# Saved raster plot for B5 at plots/rasters/24-well/(030)(000)_spike_counts/(030)(000)_spike_counts_B5_24_well_raster.png
# Saved raster plot for C5 at plots/rasters/24-well/(030)(000)_spike_counts/(030)(000)_spike_counts_C5_24_well_raster.png
# Saved raster plot for C1 at plots/rasters/24-well/(030)(000)_spike_counts/(030)(000)_spike_counts_C1_24_well_raster.png
# Saved raster plot for D1 at plots/rasters/24-well/(030)(000)_spike_counts/(030)(000)_spike_counts_D1_24_well_raster.png
# Saved raster plot for D2 at plots/rasters/24-well/(030)(000)_spike_counts/(030)(000)_spike_counts_D2_24_well_raster.png
# Processing file: (006)(000)_spike_counts.csv
# Saved raster plot for A6 at plots/rasters/24-well/(006)(000)_spike_counts/(006)(000)_spike_counts_A6_24_well_raster.png
# Saved raster plot for A1 at plots/rasters/24-well/(006)(000)_spike_counts/(006)(000)_spike_counts_A1_24_well_raster.png
# Saved raster plot for B1 at plots/rasters/24-well/(006)(000)_spike_counts/(006)(000)_spike_counts_B1_24_well_raster.png
# Saved raster plot for B2 at plots/rasters/24-well/(006)(000)_spike_counts/(006)(000)_spike_counts_B2_24_well_raster.png
# Saved raster plot for C2 at plots/rasters/24-well/(006)(000)_spike_counts/(006)(000)_spike_counts_C2_24_well_raster.png
# Saved raster plot for C1 at plots/rasters/24-well/(006)(000)_spike_counts/(006)(000)_spike_counts_C1_24_well_raster.png
# Saved raster plot for D1 at plots/rasters/24-well/(006)(000)_spike_counts/(006)(000)_spike_counts_D1_24_well_raster.png
# Saved raster plot for D2 at plots/rasters/24-well/(006)(000)_spike_counts/(006)(000)_spike_counts_D2_24_well_raster.png
# Processing file: (007)(000)_spike_counts.csv
# Saved raster plot for A1 at plots/rasters/24-well/(007)(000)_spike_counts/(007)(000)_spike_counts_A1_24_well_raster.png
# Saved raster plot for A2 at plots/rasters/24-well/(007)(000)_spike_counts/(007)(000)_spike_counts_A2_24_well_raster.png
# Saved raster plot for B1 at plots/rasters/24-well/(007)(000)_spike_counts/(007)(000)_spike_counts_B1_24_well_raster.png
# Saved raster plot for B2 at plots/rasters/24-well/(007)(000)_spike_counts/(007)(000)_spike_counts_B2_24_well_raster.png
# Saved raster plot for C1 at plots/rasters/24-well/(007)(000)_spike_counts/(007)(000)_spike_counts_C1_24_well_raster.png
# Saved raster plot for C2 at plots/rasters/24-well/(007)(000)_spike_counts/(007)(000)_spike_counts_C2_24_well_raster.png
# Saved raster plot for D4 at plots/rasters/24-well/(007)(000)_spike_counts/(007)(000)_spike_counts_D4_24_well_raster.png
# Saved raster plot for D6 at plots/rasters/24-well/(007)(000)_spike_counts/(007)(000)_spike_counts_D6_24_well_raster.png
# Processing file: (031)(000)_spike_counts.csv
# Saved raster plot for A5 at plots/rasters/24-well/(031)(000)_spike_counts/(031)(000)_spike_counts_A5_24_well_raster.png
# Saved raster plot for A2 at plots/rasters/24-well/(031)(000)_spike_counts/(031)(000)_spike_counts_A2_24_well_raster.png
# Saved raster plot for B4 at plots/rasters/24-well/(031)(000)_spike_counts/(031)(000)_spike_counts_B4_24_well_raster.png
# Saved raster plot for B1 at plots/rasters/24-well/(031)(000)_spike_counts/(031)(000)_spike_counts_B1_24_well_raster.png
# Saved raster plot for C5 at plots/rasters/24-well/(031)(000)_spike_counts/(031)(000)_spike_counts_C5_24_well_raster.png
# Saved raster plot for C4 at plots/rasters/24-well/(031)(000)_spike_counts/(031)(000)_spike_counts_C4_24_well_raster.png
# Saved raster plot for D3 at plots/rasters/24-well/(031)(000)_spike_counts/(031)(000)_spike_counts_D3_24_well_raster.png
# Saved raster plot for D2 at plots/rasters/24-well/(031)(000)_spike_counts/(031)(000)_spike_counts_D2_24_well_raster.png
# Processing file: (000)(000)_spike_counts.csv
# Saved raster plot for A1 at plots/rasters/24-well/(000)(000)_spike_counts/(000)(000)_spike_counts_A1_24_well_raster.png
# Saved raster plot for A2 at plots/rasters/24-well/(000)(000)_spike_counts/(000)(000)_spike_counts_A2_24_well_raster.png
# Saved raster plot for B1 at plots/rasters/24-well/(000)(000)_spike_counts/(000)(000)_spike_counts_B1_24_well_raster.png
# Saved raster plot for B2 at plots/rasters/24-well/(000)(000)_spike_counts/(000)(000)_spike_counts_B2_24_well_raster.png
# Saved raster plot for C4 at plots/rasters/24-well/(000)(000)_spike_counts/(000)(000)_spike_counts_C4_24_well_raster.png
# Saved raster plot for C1 at plots/rasters/24-well/(000)(000)_spike_counts/(000)(000)_spike_counts_C1_24_well_raster.png
# Saved raster plot for D3 at plots/rasters/24-well/(000)(000)_spike_counts/(000)(000)_spike_counts_D3_24_well_raster.png
# Saved raster plot for D4 at plots/rasters/24-well/(000)(000)_spike_counts/(000)(000)_spike_counts_D4_24_well_raster.png
# Processing file: (032)(000)_spike_counts.csv
# Saved raster plot for A5 at plots/rasters/24-well/(032)(000)_spike_counts/(032)(000)_spike_counts_A5_24_well_raster.png
# Saved raster plot for A2 at plots/rasters/24-well/(032)(000)_spike_counts/(032)(000)_spike_counts_A2_24_well_raster.png
# Saved raster plot for B5 at plots/rasters/24-well/(032)(000)_spike_counts/(032)(000)_spike_counts_B5_24_well_raster.png
# Saved raster plot for B1 at plots/rasters/24-well/(032)(000)_spike_counts/(032)(000)_spike_counts_B1_24_well_raster.png
# Saved raster plot for C5 at plots/rasters/24-well/(032)(000)_spike_counts/(032)(000)_spike_counts_C5_24_well_raster.png
# Saved raster plot for C4 at plots/rasters/24-well/(032)(000)_spike_counts/(032)(000)_spike_counts_C4_24_well_raster.png
# Saved raster plot for D2 at plots/rasters/24-well/(032)(000)_spike_counts/(032)(000)_spike_counts_D2_24_well_raster.png
# Saved raster plot for D1 at plots/rasters/24-well/(032)(000)_spike_counts/(032)(000)_spike_counts_D1_24_well_raster.png
# Processing file: (003)(000)_spike_counts.csv
# Saved raster plot for A1 at plots/rasters/24-well/(003)(000)_spike_counts/(003)(000)_spike_counts_A1_24_well_raster.png
# Saved raster plot for A2 at plots/rasters/24-well/(003)(000)_spike_counts/(003)(000)_spike_counts_A2_24_well_raster.png
# Saved raster plot for B1 at plots/rasters/24-well/(003)(000)_spike_counts/(003)(000)_spike_counts_B1_24_well_raster.png
# Saved raster plot for B2 at plots/rasters/24-well/(003)(000)_spike_counts/(003)(000)_spike_counts_B2_24_well_raster.png
# Saved raster plot for C4 at plots/rasters/24-well/(003)(000)_spike_counts/(003)(000)_spike_counts_C4_24_well_raster.png
# Saved raster plot for C1 at plots/rasters/24-well/(003)(000)_spike_counts/(003)(000)_spike_counts_C1_24_well_raster.png
# Saved raster plot for D4 at plots/rasters/24-well/(003)(000)_spike_counts/(003)(000)_spike_counts_D4_24_well_raster.png
# Saved raster plot for D5 at plots/rasters/24-well/(003)(000)_spike_counts/(003)(000)_spike_counts_D5_24_well_raster.png
# Processing file: (009)(000)_spike_counts.csv
# Saved raster plot for A4 at plots/rasters/24-well/(009)(000)_spike_counts/(009)(000)_spike_counts_A4_24_well_raster.png
# Saved raster plot for A5 at plots/rasters/24-well/(009)(000)_spike_counts/(009)(000)_spike_counts_A5_24_well_raster.png
# Saved raster plot for B1 at plots/rasters/24-well/(009)(000)_spike_counts/(009)(000)_spike_counts_B1_24_well_raster.png
# Saved raster plot for B2 at plots/rasters/24-well/(009)(000)_spike_counts/(009)(000)_spike_counts_B2_24_well_raster.png
# Saved raster plot for C5 at plots/rasters/24-well/(009)(000)_spike_counts/(009)(000)_spike_counts_C5_24_well_raster.png
# Saved raster plot for C1 at plots/rasters/24-well/(009)(000)_spike_counts/(009)(000)_spike_counts_C1_24_well_raster.png
# Saved raster plot for D1 at plots/rasters/24-well/(009)(000)_spike_counts/(009)(000)_spike_counts_D1_24_well_raster.png
# Saved raster plot for D2 at plots/rasters/24-well/(009)(000)_spike_counts/(009)(000)_spike_counts_D2_24_well_raster.png
# Processing file: (004)(000)_spike_counts.csv
# Saved raster plot for A1 at plots/rasters/24-well/(004)(000)_spike_counts/(004)(000)_spike_counts_A1_24_well_raster.png
# Saved raster plot for A2 at plots/rasters/24-well/(004)(000)_spike_counts/(004)(000)_spike_counts_A2_24_well_raster.png
# Saved raster plot for B6 at plots/rasters/24-well/(004)(000)_spike_counts/(004)(000)_spike_counts_B6_24_well_raster.png
# Saved raster plot for B1 at plots/rasters/24-well/(004)(000)_spike_counts/(004)(000)_spike_counts_B1_24_well_raster.png
# Saved raster plot for C1 at plots/rasters/24-well/(004)(000)_spike_counts/(004)(000)_spike_counts_C1_24_well_raster.png
# Saved raster plot for C2 at plots/rasters/24-well/(004)(000)_spike_counts/(004)(000)_spike_counts_C2_24_well_raster.png
# Saved raster plot for D1 at plots/rasters/24-well/(004)(000)_spike_counts/(004)(000)_spike_counts_D1_24_well_raster.png
# Saved raster plot for D2 at plots/rasters/24-well/(004)(000)_spike_counts/(004)(000)_spike_counts_D2_24_well_raster.png
# Processing file: (027)(000)_spike_counts.csv
# Saved raster plot for A5 at plots/rasters/24-well/(027)(000)_spike_counts/(027)(000)_spike_counts_A5_24_well_raster.png
# Saved raster plot for A6 at plots/rasters/24-well/(027)(000)_spike_counts/(027)(000)_spike_counts_A6_24_well_raster.png
# Saved raster plot for B5 at plots/rasters/24-well/(027)(000)_spike_counts/(027)(000)_spike_counts_B5_24_well_raster.png
# Saved raster plot for B1 at plots/rasters/24-well/(027)(000)_spike_counts/(027)(000)_spike_counts_B1_24_well_raster.png
# Saved raster plot for C5 at plots/rasters/24-well/(027)(000)_spike_counts/(027)(000)_spike_counts_C5_24_well_raster.png
# Saved raster plot for C6 at plots/rasters/24-well/(027)(000)_spike_counts/(027)(000)_spike_counts_C6_24_well_raster.png
# Saved raster plot for D3 at plots/rasters/24-well/(027)(000)_spike_counts/(027)(000)_spike_counts_D3_24_well_raster.png
# Saved raster plot for D5 at plots/rasters/24-well/(027)(000)_spike_counts/(027)(000)_spike_counts_D5_24_well_raster.png
# Processing file: (016)(000)_spike_counts.csv
# Saved raster plot for A4 at plots/rasters/24-well/(016)(000)_spike_counts/(016)(000)_spike_counts_A4_24_well_raster.png
# Saved raster plot for A5 at plots/rasters/24-well/(016)(000)_spike_counts/(016)(000)_spike_counts_A5_24_well_raster.png
# Saved raster plot for B1 at plots/rasters/24-well/(016)(000)_spike_counts/(016)(000)_spike_counts_B1_24_well_raster.png
# Saved raster plot for B2 at plots/rasters/24-well/(016)(000)_spike_counts/(016)(000)_spike_counts_B2_24_well_raster.png
# Saved raster plot for C1 at plots/rasters/24-well/(016)(000)_spike_counts/(016)(000)_spike_counts_C1_24_well_raster.png
# Saved raster plot for C5 at plots/rasters/24-well/(016)(000)_spike_counts/(016)(000)_spike_counts_C5_24_well_raster.png
# Saved raster plot for D1 at plots/rasters/24-well/(016)(000)_spike_counts/(016)(000)_spike_counts_D1_24_well_raster.png
# Saved raster plot for D2 at plots/rasters/24-well/(016)(000)_spike_counts/(016)(000)_spike_counts_D2_24_well_raster.png
# Processing file: (020)(000)_spike_counts.csv
# Saved raster plot for A5 at plots/rasters/24-well/(020)(000)_spike_counts/(020)(000)_spike_counts_A5_24_well_raster.png
# Saved raster plot for A1 at plots/rasters/24-well/(020)(000)_spike_counts/(020)(000)_spike_counts_A1_24_well_raster.png
# Saved raster plot for B1 at plots/rasters/24-well/(020)(000)_spike_counts/(020)(000)_spike_counts_B1_24_well_raster.png
# Saved raster plot for B2 at plots/rasters/24-well/(020)(000)_spike_counts/(020)(000)_spike_counts_B2_24_well_raster.png
# Saved raster plot for C5 at plots/rasters/24-well/(020)(000)_spike_counts/(020)(000)_spike_counts_C5_24_well_raster.png
# Saved raster plot for C3 at plots/rasters/24-well/(020)(000)_spike_counts/(020)(000)_spike_counts_C3_24_well_raster.png
# Saved raster plot for D3 at plots/rasters/24-well/(020)(000)_spike_counts/(020)(000)_spike_counts_D3_24_well_raster.png
# Saved raster plot for D4 at plots/rasters/24-well/(020)(000)_spike_counts/(020)(000)_spike_counts_D4_24_well_raster.png
# Processing file: (011)(000)_spike_counts.csv
# Saved raster plot for A4 at plots/rasters/24-well/(011)(000)_spike_counts/(011)(000)_spike_counts_A4_24_well_raster.png
# Saved raster plot for A5 at plots/rasters/24-well/(011)(000)_spike_counts/(011)(000)_spike_counts_A5_24_well_raster.png
# Saved raster plot for B3 at plots/rasters/24-well/(011)(000)_spike_counts/(011)(000)_spike_counts_B3_24_well_raster.png
# Saved raster plot for B1 at plots/rasters/24-well/(011)(000)_spike_counts/(011)(000)_spike_counts_B1_24_well_raster.png
# Saved raster plot for C5 at plots/rasters/24-well/(011)(000)_spike_counts/(011)(000)_spike_counts_C5_24_well_raster.png
# Saved raster plot for C1 at plots/rasters/24-well/(011)(000)_spike_counts/(011)(000)_spike_counts_C1_24_well_raster.png
# Saved raster plot for D5 at plots/rasters/24-well/(011)(000)_spike_counts/(011)(000)_spike_counts_D5_24_well_raster.png
# Saved raster plot for D1 at plots/rasters/24-well/(011)(000)_spike_counts/(011)(000)_spike_counts_D1_24_well_raster.png
# Processing file: (029)(000)_spike_counts.csv
# Saved raster plot for A5 at plots/rasters/24-well/(029)(000)_spike_counts/(029)(000)_spike_counts_A5_24_well_raster.png
# Saved raster plot for A4 at plots/rasters/24-well/(029)(000)_spike_counts/(029)(000)_spike_counts_A4_24_well_raster.png
# Saved raster plot for B1 at plots/rasters/24-well/(029)(000)_spike_counts/(029)(000)_spike_counts_B1_24_well_raster.png
# Saved raster plot for B4 at plots/rasters/24-well/(029)(000)_spike_counts/(029)(000)_spike_counts_B4_24_well_raster.png
# Saved raster plot for C5 at plots/rasters/24-well/(029)(000)_spike_counts/(029)(000)_spike_counts_C5_24_well_raster.png
# Saved raster plot for C6 at plots/rasters/24-well/(029)(000)_spike_counts/(029)(000)_spike_counts_C6_24_well_raster.png
# Saved raster plot for D3 at plots/rasters/24-well/(029)(000)_spike_counts/(029)(000)_spike_counts_D3_24_well_raster.png
# Saved raster plot for D5 at plots/rasters/24-well/(029)(000)_spike_counts/(029)(000)_spike_counts_D5_24_well_raster.png
# Processing file: (023)(000)_spike_counts.csv
# Saved raster plot for A5 at plots/rasters/24-well/(023)(000)_spike_counts/(023)(000)_spike_counts_A5_24_well_raster.png
# Saved raster plot for A6 at plots/rasters/24-well/(023)(000)_spike_counts/(023)(000)_spike_counts_A6_24_well_raster.png
# Saved raster plot for B4 at plots/rasters/24-well/(023)(000)_spike_counts/(023)(000)_spike_counts_B4_24_well_raster.png
# Saved raster plot for B6 at plots/rasters/24-well/(023)(000)_spike_counts/(023)(000)_spike_counts_B6_24_well_raster.png
# Saved raster plot for C5 at plots/rasters/24-well/(023)(000)_spike_counts/(023)(000)_spike_counts_C5_24_well_raster.png
# Saved raster plot for C6 at plots/rasters/24-well/(023)(000)_spike_counts/(023)(000)_spike_counts_C6_24_well_raster.png
# Saved raster plot for D6 at plots/rasters/24-well/(023)(000)_spike_counts/(023)(000)_spike_counts_D6_24_well_raster.png
# Saved raster plot for D5 at plots/rasters/24-well/(023)(000)_spike_counts/(023)(000)_spike_counts_D5_24_well_raster.png
# Processing file: (012)(000)_spike_counts.csv
# Saved raster plot for A5 at plots/rasters/24-well/(012)(000)_spike_counts/(012)(000)_spike_counts_A5_24_well_raster.png
# Saved raster plot for A4 at plots/rasters/24-well/(012)(000)_spike_counts/(012)(000)_spike_counts_A4_24_well_raster.png
# Saved raster plot for B1 at plots/rasters/24-well/(012)(000)_spike_counts/(012)(000)_spike_counts_B1_24_well_raster.png
# Saved raster plot for B2 at plots/rasters/24-well/(012)(000)_spike_counts/(012)(000)_spike_counts_B2_24_well_raster.png
# Saved raster plot for C1 at plots/rasters/24-well/(012)(000)_spike_counts/(012)(000)_spike_counts_C1_24_well_raster.png
# Saved raster plot for C2 at plots/rasters/24-well/(012)(000)_spike_counts/(012)(000)_spike_counts_C2_24_well_raster.png
# Saved raster plot for D3 at plots/rasters/24-well/(012)(000)_spike_counts/(012)(000)_spike_counts_D3_24_well_raster.png
# Saved raster plot for D5 at plots/rasters/24-well/(012)(000)_spike_counts/(012)(000)_spike_counts_D5_24_well_raster.png
# Processing file: (018)(000)_spike_counts.csv
# Saved raster plot for A5 at plots/rasters/24-well/(018)(000)_spike_counts/(018)(000)_spike_counts_A5_24_well_raster.png
# Saved raster plot for A4 at plots/rasters/24-well/(018)(000)_spike_counts/(018)(000)_spike_counts_A4_24_well_raster.png
# Saved raster plot for B4 at plots/rasters/24-well/(018)(000)_spike_counts/(018)(000)_spike_counts_B4_24_well_raster.png
# Saved raster plot for B3 at plots/rasters/24-well/(018)(000)_spike_counts/(018)(000)_spike_counts_B3_24_well_raster.png
# Saved raster plot for C5 at plots/rasters/24-well/(018)(000)_spike_counts/(018)(000)_spike_counts_C5_24_well_raster.png
# Saved raster plot for C6 at plots/rasters/24-well/(018)(000)_spike_counts/(018)(000)_spike_counts_C6_24_well_raster.png
# Saved raster plot for D2 at plots/rasters/24-well/(018)(000)_spike_counts/(018)(000)_spike_counts_D2_24_well_raster.png
# Saved raster plot for D4 at plots/rasters/24-well/(018)(000)_spike_counts/(018)(000)_spike_counts_D4_24_well_raster.png
# Processing file: (024)(000)_spike_counts.csv
# Saved raster plot for A2 at plots/rasters/24-well/(024)(000)_spike_counts/(024)(000)_spike_counts_A2_24_well_raster.png
# Saved raster plot for A5 at plots/rasters/24-well/(024)(000)_spike_counts/(024)(000)_spike_counts_A5_24_well_raster.png
# Saved raster plot for B4 at plots/rasters/24-well/(024)(000)_spike_counts/(024)(000)_spike_counts_B4_24_well_raster.png
# Saved raster plot for B1 at plots/rasters/24-well/(024)(000)_spike_counts/(024)(000)_spike_counts_B1_24_well_raster.png
# Saved raster plot for C5 at plots/rasters/24-well/(024)(000)_spike_counts/(024)(000)_spike_counts_C5_24_well_raster.png
# Saved raster plot for C6 at plots/rasters/24-well/(024)(000)_spike_counts/(024)(000)_spike_counts_C6_24_well_raster.png
# Saved raster plot for D1 at plots/rasters/24-well/(024)(000)_spike_counts/(024)(000)_spike_counts_D1_24_well_raster.png
# Saved raster plot for D2 at plots/rasters/24-well/(024)(000)_spike_counts/(024)(000)_spike_counts_D2_24_well_raster.png
# Processing file: (015)(000)_spike_counts.csv
# Saved raster plot for A4 at plots/rasters/24-well/(015)(000)_spike_counts/(015)(000)_spike_counts_A4_24_well_raster.png
# Saved raster plot for A5 at plots/rasters/24-well/(015)(000)_spike_counts/(015)(000)_spike_counts_A5_24_well_raster.png
# Saved raster plot for B1 at plots/rasters/24-well/(015)(000)_spike_counts/(015)(000)_spike_counts_B1_24_well_raster.png
# Saved raster plot for B3 at plots/rasters/24-well/(015)(000)_spike_counts/(015)(000)_spike_counts_B3_24_well_raster.png
# Saved raster plot for C5 at plots/rasters/24-well/(015)(000)_spike_counts/(015)(000)_spike_counts_C5_24_well_raster.png
# Saved raster plot for C6 at plots/rasters/24-well/(015)(000)_spike_counts/(015)(000)_spike_counts_C6_24_well_raster.png
# Saved raster plot for D1 at plots/rasters/24-well/(015)(000)_spike_counts/(015)(000)_spike_counts_D1_24_well_raster.png
# Saved raster plot for D2 at plots/rasters/24-well/(015)(000)_spike_counts/(015)(000)_spike_counts_D2_24_well_raster.png
# Processing file: (014)(000)_spike_counts.csv
# Saved raster plot for A5 at plots/rasters/24-well/(014)(000)_spike_counts/(014)(000)_spike_counts_A5_24_well_raster.png
# Saved raster plot for A1 at plots/rasters/24-well/(014)(000)_spike_counts/(014)(000)_spike_counts_A1_24_well_raster.png
# Saved raster plot for B1 at plots/rasters/24-well/(014)(000)_spike_counts/(014)(000)_spike_counts_B1_24_well_raster.png
# Saved raster plot for B4 at plots/rasters/24-well/(014)(000)_spike_counts/(014)(000)_spike_counts_B4_24_well_raster.png
# Saved raster plot for C6 at plots/rasters/24-well/(014)(000)_spike_counts/(014)(000)_spike_counts_C6_24_well_raster.png
# Saved raster plot for C5 at plots/rasters/24-well/(014)(000)_spike_counts/(014)(000)_spike_counts_C5_24_well_raster.png
# Saved raster plot for D3 at plots/rasters/24-well/(014)(000)_spike_counts/(014)(000)_spike_counts_D3_24_well_raster.png
# Saved raster plot for D1 at plots/rasters/24-well/(014)(000)_spike_counts/(014)(000)_spike_counts_D1_24_well_raster.png
# Processing file: (025)(000)_spike_counts.csv
# Saved raster plot for A1 at plots/rasters/24-well/(025)(000)_spike_counts/(025)(000)_spike_counts_A1_24_well_raster.png
# Saved raster plot for A4 at plots/rasters/24-well/(025)(000)_spike_counts/(025)(000)_spike_counts_A4_24_well_raster.png
# Saved raster plot for B4 at plots/rasters/24-well/(025)(000)_spike_counts/(025)(000)_spike_counts_B4_24_well_raster.png
# Saved raster plot for B1 at plots/rasters/24-well/(025)(000)_spike_counts/(025)(000)_spike_counts_B1_24_well_raster.png
# Saved raster plot for C5 at plots/rasters/24-well/(025)(000)_spike_counts/(025)(000)_spike_counts_C5_24_well_raster.png
# Saved raster plot for C6 at plots/rasters/24-well/(025)(000)_spike_counts/(025)(000)_spike_counts_C6_24_well_raster.png
# Saved raster plot for D2 at plots/rasters/24-well/(025)(000)_spike_counts/(025)(000)_spike_counts_D2_24_well_raster.png
# Saved raster plot for D5 at plots/rasters/24-well/(025)(000)_spike_counts/(025)(000)_spike_counts_D5_24_well_raster.png
# Processing file: (019)(000)_spike_counts.csv
# Saved raster plot for A5 at plots/rasters/24-well/(019)(000)_spike_counts/(019)(000)_spike_counts_A5_24_well_raster.png
# Saved raster plot for A1 at plots/rasters/24-well/(019)(000)_spike_counts/(019)(000)_spike_counts_A1_24_well_raster.png
# Saved raster plot for B1 at plots/rasters/24-well/(019)(000)_spike_counts/(019)(000)_spike_counts_B1_24_well_raster.png
# Saved raster plot for B3 at plots/rasters/24-well/(019)(000)_spike_counts/(019)(000)_spike_counts_B3_24_well_raster.png
# Saved raster plot for C5 at plots/rasters/24-well/(019)(000)_spike_counts/(019)(000)_spike_counts_C5_24_well_raster.png
# Saved raster plot for C1 at plots/rasters/24-well/(019)(000)_spike_counts/(019)(000)_spike_counts_C1_24_well_raster.png
# Saved raster plot for D1 at plots/rasters/24-well/(019)(000)_spike_counts/(019)(000)_spike_counts_D1_24_well_raster.png
# Saved raster plot for D4 at plots/rasters/24-well/(019)(000)_spike_counts/(019)(000)_spike_counts_D4_24_well_raster.png
# Processing file: (013)(000)_spike_counts.csv
# Saved raster plot for A5 at plots/rasters/24-well/(013)(000)_spike_counts/(013)(000)_spike_counts_A5_24_well_raster.png
# Saved raster plot for A4 at plots/rasters/24-well/(013)(000)_spike_counts/(013)(000)_spike_counts_A4_24_well_raster.png
# Saved raster plot for B1 at plots/rasters/24-well/(013)(000)_spike_counts/(013)(000)_spike_counts_B1_24_well_raster.png
# Saved raster plot for B2 at plots/rasters/24-well/(013)(000)_spike_counts/(013)(000)_spike_counts_B2_24_well_raster.png
# Saved raster plot for C3 at plots/rasters/24-well/(013)(000)_spike_counts/(013)(000)_spike_counts_C3_24_well_raster.png
# Saved raster plot for C1 at plots/rasters/24-well/(013)(000)_spike_counts/(013)(000)_spike_counts_C1_24_well_raster.png
# Saved raster plot for D1 at plots/rasters/24-well/(013)(000)_spike_counts/(013)(000)_spike_counts_D1_24_well_raster.png
# Saved raster plot for D2 at plots/rasters/24-well/(013)(000)_spike_counts/(013)(000)_spike_counts_D2_24_well_raster.png
# Processing file: (022)(000)_spike_counts.csv
# Saved raster plot for A5 at plots/rasters/24-well/(022)(000)_spike_counts/(022)(000)_spike_counts_A5_24_well_raster.png
# Saved raster plot for A4 at plots/rasters/24-well/(022)(000)_spike_counts/(022)(000)_spike_counts_A4_24_well_raster.png
# Saved raster plot for B4 at plots/rasters/24-well/(022)(000)_spike_counts/(022)(000)_spike_counts_B4_24_well_raster.png
# Saved raster plot for B1 at plots/rasters/24-well/(022)(000)_spike_counts/(022)(000)_spike_counts_B1_24_well_raster.png
# Saved raster plot for C5 at plots/rasters/24-well/(022)(000)_spike_counts/(022)(000)_spike_counts_C5_24_well_raster.png
# Saved raster plot for C3 at plots/rasters/24-well/(022)(000)_spike_counts/(022)(000)_spike_counts_C3_24_well_raster.png
# Saved raster plot for D5 at plots/rasters/24-well/(022)(000)_spike_counts/(022)(000)_spike_counts_D5_24_well_raster.png
# Saved raster plot for D3 at plots/rasters/24-well/(022)(000)_spike_counts/(022)(000)_spike_counts_D3_24_well_raster.png
# Processing file: (028)(000)_spike_counts.csv
# Saved raster plot for A5 at plots/rasters/24-well/(028)(000)_spike_counts/(028)(000)_spike_counts_A5_24_well_raster.png
# Saved raster plot for A2 at plots/rasters/24-well/(028)(000)_spike_counts/(028)(000)_spike_counts_A2_24_well_raster.png
# Saved raster plot for B5 at plots/rasters/24-well/(028)(000)_spike_counts/(028)(000)_spike_counts_B5_24_well_raster.png
# Saved raster plot for B1 at plots/rasters/24-well/(028)(000)_spike_counts/(028)(000)_spike_counts_B1_24_well_raster.png
# Saved raster plot for C5 at plots/rasters/24-well/(028)(000)_spike_counts/(028)(000)_spike_counts_C5_24_well_raster.png
# Saved raster plot for C4 at plots/rasters/24-well/(028)(000)_spike_counts/(028)(000)_spike_counts_C4_24_well_raster.png
# Saved raster plot for D3 at plots/rasters/24-well/(028)(000)_spike_counts/(028)(000)_spike_counts_D3_24_well_raster.png
# Saved raster plot for D2 at plots/rasters/24-well/(028)(000)_spike_counts/(028)(000)_spike_counts_D2_24_well_raster.png
# Processing file: (010)(000)_spike_counts.csv
# Saved raster plot for A4 at plots/rasters/24-well/(010)(000)_spike_counts/(010)(000)_spike_counts_A4_24_well_raster.png
# Saved raster plot for A1 at plots/rasters/24-well/(010)(000)_spike_counts/(010)(000)_spike_counts_A1_24_well_raster.png
# Saved raster plot for B1 at plots/rasters/24-well/(010)(000)_spike_counts/(010)(000)_spike_counts_B1_24_well_raster.png
# Saved raster plot for B2 at plots/rasters/24-well/(010)(000)_spike_counts/(010)(000)_spike_counts_B2_24_well_raster.png
# Saved raster plot for C5 at plots/rasters/24-well/(010)(000)_spike_counts/(010)(000)_spike_counts_C5_24_well_raster.png
# Saved raster plot for C1 at plots/rasters/24-well/(010)(000)_spike_counts/(010)(000)_spike_counts_C1_24_well_raster.png
# Saved raster plot for D1 at plots/rasters/24-well/(010)(000)_spike_counts/(010)(000)_spike_counts_D1_24_well_raster.png
# Saved raster plot for D2 at plots/rasters/24-well/(010)(000)_spike_counts/(010)(000)_spike_counts_D2_24_well_raster.png
# Processing file: (021)(000)_spike_counts.csv
# Saved raster plot for A5 at plots/rasters/24-well/(021)(000)_spike_counts/(021)(000)_spike_counts_A5_24_well_raster.png
# Saved raster plot for A1 at plots/rasters/24-well/(021)(000)_spike_counts/(021)(000)_spike_counts_A1_24_well_raster.png
# Saved raster plot for B4 at plots/rasters/24-well/(021)(000)_spike_counts/(021)(000)_spike_counts_B4_24_well_raster.png
# Saved raster plot for B1 at plots/rasters/24-well/(021)(000)_spike_counts/(021)(000)_spike_counts_B1_24_well_raster.png
# Saved raster plot for C5 at plots/rasters/24-well/(021)(000)_spike_counts/(021)(000)_spike_counts_C5_24_well_raster.png
# Saved raster plot for C3 at plots/rasters/24-well/(021)(000)_spike_counts/(021)(000)_spike_counts_C3_24_well_raster.png
# Saved raster plot for D3 at plots/rasters/24-well/(021)(000)_spike_counts/(021)(000)_spike_counts_D3_24_well_raster.png
# Saved raster plot for D2 at plots/rasters/24-well/(021)(000)_spike_counts/(021)(000)_spike_counts_D2_24_well_raster.png
# Processing file: (017)(000)_spike_counts.csv
# Saved raster plot for A4 at plots/rasters/24-well/(017)(000)_spike_counts/(017)(000)_spike_counts_A4_24_well_raster.png
# Saved raster plot for A5 at plots/rasters/24-well/(017)(000)_spike_counts/(017)(000)_spike_counts_A5_24_well_raster.png
# Saved raster plot for B1 at plots/rasters/24-well/(017)(000)_spike_counts/(017)(000)_spike_counts_B1_24_well_raster.png
# Saved raster plot for B3 at plots/rasters/24-well/(017)(000)_spike_counts/(017)(000)_spike_counts_B3_24_well_raster.png
# Saved raster plot for C5 at plots/rasters/24-well/(017)(000)_spike_counts/(017)(000)_spike_counts_C5_24_well_raster.png
# Saved raster plot for C1 at plots/rasters/24-well/(017)(000)_spike_counts/(017)(000)_spike_counts_C1_24_well_raster.png
# Saved raster plot for D3 at plots/rasters/24-well/(017)(000)_spike_counts/(017)(000)_spike_counts_D3_24_well_raster.png
# Saved raster plot for D1 at plots/rasters/24-well/(017)(000)_spike_counts/(017)(000)_spike_counts_D1_24_well_raster.png
# Processing file: (026)(000)_spike_counts.csv
# Saved raster plot for A5 at plots/rasters/24-well/(026)(000)_spike_counts/(026)(000)_spike_counts_A5_24_well_raster.png
# Saved raster plot for A4 at plots/rasters/24-well/(026)(000)_spike_counts/(026)(000)_spike_counts_A4_24_well_raster.png
# Saved raster plot for B5 at plots/rasters/24-well/(026)(000)_spike_counts/(026)(000)_spike_counts_B5_24_well_raster.png
# Saved raster plot for B1 at plots/rasters/24-well/(026)(000)_spike_counts/(026)(000)_spike_counts_B1_24_well_raster.png
# Saved raster plot for C5 at plots/rasters/24-well/(026)(000)_spike_counts/(026)(000)_spike_counts_C5_24_well_raster.png
# Saved raster plot for C1 at plots/rasters/24-well/(026)(000)_spike_counts/(026)(000)_spike_counts_C1_24_well_raster.png
# Saved raster plot for D2 at plots/rasters/24-well/(026)(000)_spike_counts/(026)(000)_spike_counts_D2_24_well_raster.png
# Saved raster plot for D1 at plots/rasters/24-well/(026)(000)_spike_counts/(026)(000)_spike_counts_D1_24_well_raster.png
